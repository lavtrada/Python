# %%
import pandas as pd
import numpy as np
train_data=pd.read_csv("Salary_Table.csv")
predict_data=pd.read_excel("predict_data.xlsx")
train_data['Date_Time']=pd.to_datetime(train_data['Date_Time'],errors='coerce')
predict_data['Date_Time']=pd.to_datetime(predict_data['Date_Time'],errors='coerce')
# train_data = train_data.dropna(subset=['Date_Time', 'Experience', 'Previous_Salary', 'Current_Salary'])
# predict_data = predict_data.dropna(subset=['Date_Time', 'Experience', 'Previous_Salary'])
X_train=train_data[['Experience','Previous_Salary']]
y_train=train_data['Current_Salary']
X_predict=predict_data[['Experience','Previous_Salary']]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=20)
reg=LinearRegression()
reg.fit(X_train,y_train)
reg.predict(X_test)
# Out:
#   Cell In[171], line 11
#     X_predict=predict_data[['Experience,'Previous_Salary']]
#                                                         ^
# SyntaxError: unterminated string literal (detected at line 11)

# %%
predict_data
# Out:
#    Date_Time  Experience   Previous_Salary
# 0 2025-01-09            2     5.000000e+05
# 1 2025-01-10            4     8.000000e+05
# 2 2025-01-11            6     9.000000e+05
# 3 2025-01-12            9     1.133333e+06
# 4 2025-01-13            7     1.333333e+06
# 5 2025-01-14            1     1.533333e+06
# 6 2025-01-15            3     1.733333e+06
# 7 2025-01-16            4     1.933333e+06

# %%
# Out:
# LinearRegression()

# %%
reg.predict(15,5500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 reg.predict(15,5500)
#
# TypeError: LinearModel.predict() takes 2 positional arguments but 3 were given
