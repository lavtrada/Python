# %%
import pandas as pd
df=pd.read_csv("mba_decision_dataset.csv")
df.head(50)
# Out:
#     Person ID   Age  Gender Undergraduate Major  Undergraduate GPA  \
# 0         1.0  27.0    Male                Arts               3.18
# 1         2.0  24.0    Male                Arts               3.03
# 2         3.0  33.0  Female            Business               3.66
# 3         4.0  31.0    Male         Engineering               2.46
# 4         5.0  28.0  Female            Business               2.75
# 5         6.0  33.0    Male            Business               3.58
# 6         7.0  25.0  Female                Arts               3.06
# 7         8.0  27.0    Male         Engineering               2.80
# 8         9.0  30.0  Female                Arts               2.06
# 9        10.0  23.0  Female                Arts               3.51
# 10       11.0  27.0    Male                Arts               3.94
# 11       12.0  31.0   Other                Arts               3.24
# 12       13.0  31.0    Male           Economics               3.71
# ...

# %%
df["Age"].head()
# Out:
# 0    27.0
# 1    24.0
# 2    33.0
# 3    31.0
# 4    28.0
# Name: Age, dtype: float64

# %%
df[df["Gender"]=="Male"].head(50)
# Out:
#      Person ID   Age Gender Undergraduate Major  Undergraduate GPA  \
# 0          1.0  27.0   Male                Arts               3.18
# 1          2.0  24.0   Male                Arts               3.03
# 3          4.0  31.0   Male         Engineering               2.46
# 5          6.0  33.0   Male            Business               3.58
# 7          8.0  27.0   Male         Engineering               2.80
# 10        11.0  27.0   Male                Arts               3.94
# 12        13.0  31.0   Male           Economics               3.71
# 15        16.0  24.0   Male           Economics               2.03
# 16        17.0  28.0   Male             Science               3.31
# 17        18.0  28.0   Male             Science               2.99
# 18        19.0  23.0   Male             Science               3.56
# 19        20.0  26.0   Male           Economics               3.39
# 20        21.0  25.0   Male         Engineering               3.98
# ...

# %%
df.sort_values("Age", ascending=False).head()
# Out:
#       Person ID   Age  Gender Undergraduate Major  Undergraduate GPA  \
# 5340     5341.0  34.0  Female           Economics               2.24
# 2979     2980.0  34.0    Male            Business               3.26
# 3062     3063.0  34.0  Female         Engineering               3.51
# 3039     3040.0  34.0  Female            Business               3.69
# 3038     3039.0  34.0    Male             Science               2.07
#
#       Years of Work Experience Current Job Title  Annual Salary (Before MBA)  \
# 5340                       0.0           Manager                       66232
# 2979                       8.0           Analyst                      110449
# 3062                       2.0        Consultant                       89022
# 3039                       9.0           Manager                       79358
# 3038                       3.0          Engineer                      117840
#
#      Has Management Experience  GRE/GMAT Score  Undergrad University Ranking  \
# ...

# %%
df["Has Management Experience"]=df["Has Management Experience"].replace({
    "Yes":True,
    "No":False
})
df["Has Management Experience"]=df["Has Management Experience"].astype(bool)

# %%
Experience = df.groupby("Has Management Experience")
experience=Experience.mean()
print(experience)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File F:\Data Mining\python\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File F:\Data Mining\python\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File F:\Data Mining\python\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
# Replace "Yes" with True and "No" with False
df["Has Management Experience"] = df["Has Management Experience"].replace({
    "Yes": True,
    "No": False
})

# Convert to boolean type (optional but ensures consistency)
df["Has Management Experience"] = df["Has Management Experience"].astype(bool)

# Group by "Has Management Experience" and calculate the mean
Experience = df.groupby("Has Management Experience")
experience = Experience.mean(numeric_only=True)  # Only numeric columns are included
print(experience)
# Out:
#                              Person ID        Age  Undergraduate GPA  \
# Has Management Experience
# False                      5002.088035  27.477118           2.992604
# True                       4999.340100  27.520551           2.990158
#
#                            Years of Work Experience  \
# Has Management Experience
# False                                      4.564986
# True                                       4.485213
#
#                            Annual Salary (Before MBA)  GRE/GMAT Score  \
# Has Management Experience
# False                                    75383.566484      524.440080
# True                                     74839.441994      524.289513
#
#                            Undergrad University Ranking  \
# Has Management Experience
# False                                        246.763981
# True                                         247.584504
#
#                            Entrepreneurial Interest  Networking Importance  \
# ...

# %%
df["Gender"]=df["Gender"].replace({
    "Male":1,
    "Female":2
})

# %%
df
# Out:
#       Person ID   Age Gender Undergraduate Major  Undergraduate GPA  \
# 0           1.0  27.0      1                Arts               3.18
# 1           2.0  24.0      1                Arts               3.03
# 2           3.0  33.0      2            Business               3.66
# 3           4.0  31.0      1         Engineering               2.46
# 4           5.0  28.0      2            Business               2.75
# ...         ...   ...    ...                 ...                ...
# 9995     9996.0  33.0      2           Economics               3.55
# 9996     9997.0  30.0      2            Business               2.48
# 9997     9998.0  31.0      2           Economics               2.86
# 9998     9999.0  22.0      2                Arts               2.30
# 9999    10000.0  22.0      1                Arts               2.86
#
#       Years of Work Experience Current Job Title  Annual Salary (Before MBA)  \
# ...
