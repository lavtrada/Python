# %%
import ltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer 
import re #for regular expression
import pandas as pd

# %%
data=pd.read_csv("tripadvisor_hotel_reviews.csv")
data
# Out:
#                                                 Review  Rating
# 0    nice hotel expensive parking got good deal sta...       4
# 1    ok nothing special charge diamond member hilto...       2
# 2    nice rooms not 4* experience hotel monaco seat...       3
# 3    unique, great stay, wonderful time hotel monac...       5
# 4    great stay great stay, went seahawk game aweso...       5
# ..                                                 ...     ...
# 104  fairmont hotel singapore splendid, stayed fair...       5
# 105  great hotel stayed hotel night route perth chr...       4
# 106  great hotel centre stayed 5 nights room overlo...       4
# 107  great location great value great hotel husband...       5
# 108  lovely hotel great location stayed vacation to...       5
#
# [109 rows x 2 columns]

# %%
data['Review'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data['Review'][0]
#
# NameError: name 'data' is not defined

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\nlp\lib\site-packages\confection\__init__.py:38
#      37 try:
# ---> 38     from pydantic.v1 import BaseModel, Extra, ValidationError, create_model
#      39     from pydantic.v1.fields import ModelField
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\__init__.py:5
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\_migration.py:4
#       2 from typing import Any, Callable
# ----> 4 from .version import version_short
#       6 MOVED_IN_V2 = {
#       7     'pydantic.utils:version_info': 'pydantic.version:version_info',
#       8     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      13     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      14 }
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\version.py:5
#       3 from __future__ import annotations as _annotations
# ----> 5 from pydantic_core import __version__ as __pydantic_core_version__
#       7 __all__ = 'VERSION', 'version_info'
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic_core\__init__.py:6
#       4 from typing import Any as _Any
# ----> 6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#       9     PydanticCustomError,
#      10     PydanticKnownError,
#      11     PydanticOmit,
#      12     PydanticSerializationError,
#      13     PydanticSerializationUnexpectedValue,
#      14     PydanticUndefined,
#      15     PydanticUndefinedType,
#      16     PydanticUseDefault,
#      17     SchemaError,
#      18     SchemaSerializer,
#      19     SchemaValidator,
#      20     Some,
#      21     TzInfo,
#      22     Url,
#      23     ValidationError,
#      24     __version__,
#      25     from_json,
#      26     to_json,
#      27     to_jsonable_python,
#      28     validate_core_schema,
#      29 )
#      30 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#
# ModuleNotFoundError: No module named 'pydantic_core._pydantic_core'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import spacy
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~\anaconda3\envs\nlp\lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~\anaconda3\envs\nlp\lib\site-packages\thinc\config.py:2
#       1 import catalogue
# ----> 2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
#       5 from .types import Decorator
#
# File ~\anaconda3\envs\nlp\lib\site-packages\confection\__init__.py:42
#      40     from pydantic.v1.main import ModelMetaclass
#      41 except ImportError:
# ---> 42     from pydantic import BaseModel, create_model, ValidationError, Extra  # type: ignore
#      43     from pydantic.main import ModelMetaclass  # type: ignore
#      44     from pydantic.fields import ModelField  # type: ignore
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\__init__.py:5
#       2 from importlib import import_module
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION
#       8 if typing.TYPE_CHECKING:
#       9     # import of virtually everything is supported via `__getattr__` below,
#      10     # but we need them here for type checking and IDE support
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from .version import version_short
#       6 MOVED_IN_V2 = {
#       7     'pydantic.utils:version_info': 'pydantic.version:version_info',
#       8     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      13     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      14 }
#      16 DEPRECATED_MOVED_IN_V2 = {
#      17     'pydantic.tools:schema_of': 'pydantic.deprecated.tools:schema_of',
#      18     'pydantic.tools:parse_obj_as': 'pydantic.deprecated.tools:parse_obj_as',
#    (...)
#      28     'pydantic.config:Extra': 'pydantic.deprecated.config:Extra',
#      29 }
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\version.py:5
#       1 """The `version` module holds the version information for Pydantic."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from pydantic_core import __version__ as __pydantic_core_version__
#       7 __all__ = 'VERSION', 'version_info'
#       9 VERSION = '2.11.4'
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic_core\__init__.py:6
#       3 import sys as _sys
#       4 from typing import Any as _Any
# ----> 6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#       9     PydanticCustomError,
#      10     PydanticKnownError,
#      11     PydanticOmit,
#      12     PydanticSerializationError,
#      13     PydanticSerializationUnexpectedValue,
#      14     PydanticUndefined,
#      15     PydanticUndefinedType,
#      16     PydanticUseDefault,
#      17     SchemaError,
#      18     SchemaSerializer,
#      19     SchemaValidator,
#      20     Some,
#      21     TzInfo,
#      22     Url,
#      23     ValidationError,
#      24     __version__,
#      25     from_json,
#      26     to_json,
#      27     to_jsonable_python,
#      28     validate_core_schema,
#      29 )
#      30 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#      32 if _sys.version_info < (3, 11):
#
# ModuleNotFoundError: No module named 'pydantic_core._pydantic_core'

# %%
data['Review_lowercase']=data['Review'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data['Review_lowercase']=data['Review'].str.lower()
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword=stopwords.words('english')
stopword.remove("not")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nltk.download('stopwords')
#       2 from nltk.corpus import stopwords
#       3 stopword=stopwords.words('english')
#
# NameError: name 'nltk' is not defined

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\nlp\lib\site-packages\confection\__init__.py:38
#      37 try:
# ---> 38     from pydantic.v1 import BaseModel, Extra, ValidationError, create_model
#      39     from pydantic.v1.fields import ModelField
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\__init__.py:5
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\_migration.py:4
#       2 from typing import Any, Callable
# ----> 4 from .version import version_short
#       6 MOVED_IN_V2 = {
#       7     'pydantic.utils:version_info': 'pydantic.version:version_info',
#       8     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      13     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      14 }
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\version.py:5
#       3 from __future__ import annotations as _annotations
# ----> 5 from pydantic_core import __version__ as __pydantic_core_version__
#       7 __all__ = 'VERSION', 'version_info'
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic_core\__init__.py:6
#       4 from typing import Any as _Any
# ----> 6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#       9     PydanticCustomError,
#      10     PydanticKnownError,
#      11     PydanticOmit,
#      12     PydanticSerializationError,
#      13     PydanticSerializationUnexpectedValue,
#      14     PydanticUndefined,
#      15     PydanticUndefinedType,
#      16     PydanticUseDefault,
#      17     SchemaError,
#      18     SchemaSerializer,
#      19     SchemaValidator,
#      20     Some,
#      21     TzInfo,
#      22     Url,
#      23     ValidationError,
#      24     __version__,
#      25     from_json,
#      26     to_json,
#      27     to_jsonable_python,
#      28     validate_core_schema,
#      29 )
#      30 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#
# ModuleNotFoundError: No module named 'pydantic_core._pydantic_core'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import spacy
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\anaconda3\envs\nlp\lib\site-packages\spacy\compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~\anaconda3\envs\nlp\lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~\anaconda3\envs\nlp\lib\site-packages\thinc\config.py:2
#       1 import catalogue
# ----> 2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
#       5 from .types import Decorator
#
# File ~\anaconda3\envs\nlp\lib\site-packages\confection\__init__.py:42
#      40     from pydantic.v1.main import ModelMetaclass
#      41 except ImportError:
# ---> 42     from pydantic import BaseModel, create_model, ValidationError, Extra  # type: ignore
#      43     from pydantic.main import ModelMetaclass  # type: ignore
#      44     from pydantic.fields import ModelField  # type: ignore
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\__init__.py:5
#       2 from importlib import import_module
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION
#       8 if typing.TYPE_CHECKING:
#       9     # import of virtually everything is supported via `__getattr__` below,
#      10     # but we need them here for type checking and IDE support
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from .version import version_short
#       6 MOVED_IN_V2 = {
#       7     'pydantic.utils:version_info': 'pydantic.version:version_info',
#       8     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      13     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      14 }
#      16 DEPRECATED_MOVED_IN_V2 = {
#      17     'pydantic.tools:schema_of': 'pydantic.deprecated.tools:schema_of',
#      18     'pydantic.tools:parse_obj_as': 'pydantic.deprecated.tools:parse_obj_as',
#    (...)
#      28     'pydantic.config:Extra': 'pydantic.deprecated.config:Extra',
#      29 }
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic\version.py:5
#       1 """The `version` module holds the version information for Pydantic."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from pydantic_core import __version__ as __pydantic_core_version__
#       7 __all__ = 'VERSION', 'version_info'
#       9 VERSION = '2.11.4'
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pydantic_core\__init__.py:6
#       3 import sys as _sys
#       4 from typing import Any as _Any
# ----> 6 from ._pydantic_core import (
#       7     ArgsKwargs,
#       8     MultiHostUrl,
#       9     PydanticCustomError,
#      10     PydanticKnownError,
#      11     PydanticOmit,
#      12     PydanticSerializationError,
#      13     PydanticSerializationUnexpectedValue,
#      14     PydanticUndefined,
#      15     PydanticUndefinedType,
#      16     PydanticUseDefault,
#      17     SchemaError,
#      18     SchemaSerializer,
#      19     SchemaValidator,
#      20     Some,
#      21     TzInfo,
#      22     Url,
#      23     ValidationError,
#      24     __version__,
#      25     from_json,
#      26     to_json,
#      27     to_jsonable_python,
#      28     validate_core_schema,
#      29 )
#      30 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#      32 if _sys.version_info < (3, 11):
#
# ModuleNotFoundError: No module named 'pydantic_core._pydantic_core'
