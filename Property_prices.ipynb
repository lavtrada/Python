# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Property_prices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
medi=df.bedrooms.median()

# %%
df.bedrooms=df.bedrooms.fillna(df.bedrooms.median())

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 reg=LinearRegression().fit(train_X, train_y)
#
# NameError: name 'train_X' is not defined

# %%
reg.score(test_X, test_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 reg.score(test_X, test_y)
#
# NameError: name 'reg' is not defined

# %%
reg.score(train_X,train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 reg.score(train_X,train_y)
#
# NameError: name 'reg' is not defined

# %% [raw]
# reg.coef_

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 from sklearn import linear_model
#       2 lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
# ----> 3 lasso_reg.fit(train_X, train_y)
#
# NameError: name 'train_X' is not defined

# %%
lasso_reg.score(test_X, test_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 lasso_reg.score(test_X, test_y)
#
# NameError: name 'test_X' is not defined

# %%
lasso_reg.score(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 lasso_reg.score(train_X, train_y)
#
# NameError: name 'train_X' is not defined

# %%
from sklearn.linear_model import Ridge
ridge_reg= Ridge(alpha=50, max_iter=100, tol=0.1)
ridge_reg.fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 from sklearn.linear_model import Ridge
#       2 ridge_reg= Ridge(alpha=50, max_iter=100, tol=0.1)
# ----> 3 ridge_reg.fit(train_X, train_y)
#
# NameError: name 'train_X' is not defined

# %%
ridge_reg.score(test_X, test_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 ridge_reg.score(test_X, test_y)
#
# NameError: name 'test_X' is not defined

# %%
ridge_reg.score(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 ridge_reg.score(train_X, train_y)
#
# NameError: name 'train_X' is not defined

# %%
reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 reg.intercept_
#
# NameError: name 'reg' is not defined

# %% [raw]
# reg.predict([[3000,3,40]])

# %%
print(reg.predict([[3000, 3, 40]]))
print(reg.predict([[2500,4,5]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 print(reg.predict([[3000, 3, 40]]))
#       2 print(reg.predict([[2500,4,5]]))
#
# NameError: name 'reg' is not defined
