# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_excel("Days on Disease.xlsx")
le_Disease=LabelEncoder()
df['Disease_lable']=le_Disease.fit_transform(df['Disease'])

# %%
# Out:
#     Name   Age Gender Disease  Stage   Comorbidities   Lifestyle Factor  \
# 0  milan  18.0   male  cancer      1        Diabitis     Unhealthy Food
# 1    abc  20.0   male  cancer      1  Blood Pressure  Physical Activity
# 2    xyz  25.0   male  cancer      2        Diabitis     Unhealthy Food
# 3    sdj  41.0   male  cancer      2  Blood Pressure  Physical Activity
# 4   scdc  50.0   male  cancer      4        Diabitis     Unhealthy Food
#
#    Days left  Disease_lable
# 0         60              0
# 1         60              0
# 2         50              0
# 3         50              0
# 4          1              0
